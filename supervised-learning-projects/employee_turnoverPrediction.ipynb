# %%
import pandas as pd
import numpy as np

df = pd.read_csv("employee_turnover.csv")

df
# Out:
#       Job_Satisfaction  Performance_Rating  Years_At_Company  \
# 0             0.562326            0.141129          0.123989
# 1             0.017041            0.559047          0.511203
# 2             0.774699            0.604371          0.798174
# 3             0.628174            0.385249          0.230104
# 4             0.799183            0.199967          0.839029
# ...                ...                 ...               ...
# 1345          0.914733            0.965914          0.147215
# 1346          0.396906            0.182952          0.877941
# 1347          0.099171            0.363498          0.849120
# 1348          0.048193            0.453892          0.640611
# 1349          0.496702            0.523527          0.779612
#
#       Work_Life_Balance  Distance_From_Home  Monthly_Income  Education_Level  \
# 0              0.347583            0.330353        0.328853         0.600933
# ...

# %%
df.shape
# Out:
# (1350, 16)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1350 entries, 0 to 1349
# Data columns (total 16 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Job_Satisfaction                         1350 non-null   float64
#  1   Performance_Rating                       1350 non-null   float64
#  2   Years_At_Company                         1350 non-null   float64
#  3   Work_Life_Balance                        1350 non-null   float64
#  4   Distance_From_Home                       1350 non-null   float64
#  5   Monthly_Income                           1350 non-null   float64
#  6   Education_Level                          1350 non-null   float64
#  7   Age                                      1350 non-null   float64
#  8   Num_Companies_Worked                     1350 non-null   float64
#  9   Employee_Role                            1350 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Job_Satisfaction  Performance_Rating  Years_At_Company  \
# count       1350.000000         1350.000000       1350.000000
# mean           0.506386            0.487061          0.484761
# std            0.291505            0.283808          0.282758
# min            0.001738            0.000546          0.001545
# 25%            0.263051            0.238538          0.249651
# 50%            0.525340            0.468457          0.485414
# 75%            0.750987            0.724088          0.721622
# max            0.998692            0.999957          0.999722
#
#        Work_Life_Balance  Distance_From_Home  Monthly_Income  Education_Level  \
# count        1350.000000         1350.000000     1350.000000      1350.000000
# mean            0.499442            0.494884        0.509909         0.504329
# std             0.293013            0.289248        0.290110         0.295693
# min             0.000166            0.001319        0.005015         0.000424
# ...

# %%
df.isnull().sum()
# Out:
# Job_Satisfaction                           0
# Performance_Rating                         0
# Years_At_Company                           0
# Work_Life_Balance                          0
# Distance_From_Home                         0
# Monthly_Income                             0
# Education_Level                            0
# Age                                        0
# Num_Companies_Worked                       0
# Employee_Role                              0
# Annual_Bonus                               0
# Training_Hours                             0
# Department                                 0
# Annual_Bonus_Squared                       0
# Annual_Bonus_Training_Hours_Interaction    0
# Employee_Turnover                          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(450)

# %%
x = df.drop("Employee_Turnover", axis=1)
y = df["Employee_Turnover"]

# %%
#Train Test Split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
# Baseline Logistic Regression
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=500)
lr.fit(x_train, y_train)

# L1 Regularizaiton (Lasso)
lasso = LogisticRegression(penalty='l1', solver='liblinear', C=0.05)
lasso.fit(x_train, y_train)

# L2 Regularizatio (Ridge)

ridge = LogisticRegression(penalty='l2', C=1, max_iter=500)
ridge.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1, max_iter=500)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix , classification_report

model = {"Baseline": lr, "Lasso": lasso, "Ridge": ridge}

for name,model in model.items():
    y_pred = model.predict(x_test)
    print(f"\n{name}:")
    print("Accuracy:", accuracy_score(y_test, y_pred)*100,"%")
    print("Precision:", precision_score(y_test, y_pred)*100,"%")
    print("Recall:", recall_score(y_test, y_pred)*100,"%")
    print("F1:", f1_score(y_test, y_pred)*100,"%")
    print("Confusion Matrix: ", confusion_matrix(y_test, y_pred)*100,"%")
    print(classification_report(y_test, y_pred))
# Out:
# Baseline:
# Accuracy: 85.92592592592592 %
# Precision: 87.17948717948718 %
# Recall: 81.6 %
# F1: 84.29752066115702 %
# Confusion Matrix:  [[13000  1500]
#  [ 2300 10200]] %
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.87       145
#            1       0.87      0.82      0.84       125
#
#     accuracy                           0.86       270
#    macro avg       0.86      0.86      0.86       270
# weighted avg       0.86      0.86      0.86       270
#
#
# Lasso:
# Accuracy: 81.48148148148148 %
# Precision: 76.97841726618705 %
# Recall: 85.6 %
# F1: 81.06060606060606 %
# Confusion Matrix:  [[11300  3200]
#  [ 1800 10700]] %
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82       145
#            1       0.77      0.86      0.81       125
#
#     accuracy                           0.81       270
#    macro avg       0.82      0.82      0.81       270
# ...
